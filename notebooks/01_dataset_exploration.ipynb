# %%
import pandas as pd
m = pd.read_parquet('../data/processed/image_id_mapping.parquet')
m.split.value_counts()

# %%
from collections import Counter
c = Counter(i for g in m[m.split=='valid'].gt_instruments for i in g)
sorted(c.items(), key=lambda kv:-kv[1])
